# %%
 from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

path = "/content/gdrive/MyDrive/PBL5_Quoc"
os.chdir(path)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 15705 (delta 8), reused 18 (delta 4), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.51 MiB | 14.00 MiB/s, done.
# Resolving deltas: 100% (10749/10749), done.

# %%
# !pip install -r /content/gdrive/MyDrive/PBL5_Quoc/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 23.5 MB/s eta 0:00:00
# ...

# %%
# !unrar x /content/gdrive/MyDrive/PBL5_Quoc/coco128.rar

# %%
# !python /content/gdrive/MyDrive/PBL5_Quoc/yolov5/train.py --img 640 --batch 24 --epochs 3 --data coco128.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python /content/gdrive/MyDrive/PBL5_Quoc/yolov5/train.py --img 640 --batch 24 --epochs 3 --data coco128.yaml --weights /content/gdrive/MyDrive/PBL5_Quoc/yolov5/runs/train/exp6/weights/best.pt
# Out:
# train: weights=/content/gdrive/MyDrive/PBL5_Quoc/yolov5/runs/train/exp6/weights/best.pt, cfg=, data=coco128.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python /content/gdrive/MyDrive/PBL5_Quoc/yolov5/detect.py --source /content/gdrive/MyDrive/PBL5_Quoc/yolov5/data/images/taive.jpg
# Out:
# detect: weights=/content/gdrive/MyDrive/PBL5_Quoc/yolov5/runs/train/exp7/weights/best.pt, source=/content/gdrive/MyDrive/PBL5_Quoc/yolov5/data/images/taive.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/gdrive/MyDrive/PBL5_Quoc/yolov5/data/images/taive.jpg: 416x640 (no detections), 64.9ms
# Speed: 0.6ms pre-process, 64.9ms inference, 0.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp7
